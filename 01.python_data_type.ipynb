# %%
# 문제 1
age_input = "25"
age_output = int(25) + 10
print(f"10년 뒤 당신은 {age_output}세가 됩니다.")
# Out:
# 10년 뒤 당신은 35세가 됩니다.

# %%
# 문제 2
fruits = ["사과", "바나나", "사과", "포도", "바나나", "체리"]
unique_fruits = set(fruits)
sorted_fruits = sorted(unique_fruits)
print(f"정렬된 과일 목록: {sorted_fruits}")
# Out:
# 정렬된 과일 목록: ['바나나', '사과', '체리', '포도']

# %%
# 문제 3
scores = {"국어": 90, "수학": 85, "영어": 95}

print(scores.get('국어'))
print(scores.get('수학'))          # None 변환(에러 없음)
print(scores.get('영어'))
print(scores.get("과학","해당 과목의 점수가 없습니다."))
# Out:
# 90
# 85
# 95
# 해당 과목의 점수가 없습니다.

# %%
# 문제 4
point1 = (10, 20)
point2 = (30, 40)
all_points = list(point1 + point2)
print(all_points)
# Out:
# [10, 20, 30, 40]

# %%
# 문제 5
keyword = input("검색어 입력: ")
search_keyword = keyword.strip()

if search_keyword:
    print(f"'{search_keyword}'를 검색합니다.")
else:
    print("검색어를 입력해주세요.")
# Out:
# '카카오'를 검색합니다.
